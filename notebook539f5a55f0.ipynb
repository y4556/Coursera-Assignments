# %%
! git clone https://github.com/lyuwenyu/RT-DETR.git
# Out:
# Cloning into 'RT-DETR'...
# remote: Enumerating objects: 934, done.
# remote: Counting objects: 100% (422/422), done.
# remote: Compressing objects: 100% (245/245), done.
# remote: Total 934 (delta 244), reused 276 (delta 171), pack-reused 512 (from 1)
# Receiving objects: 100% (934/934), 597.30 KiB | 11.27 MiB/s, done.
# Resolving deltas: 100% (442/442), done.

# %%
import os 
os.getcwd()

# %%
# !pip install -r "/kaggle/input/rt_detr8/pytorch/default/1/RT_DETR2/RT-DETR/rtdetr_pytorch/requirements.txt"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 9.1 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 17.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 23.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 86.7 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 66.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.6 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !python "/kaggle/input/rt_detr8/pytorch/default/1/RT_DETR2/RT-DETR/rtdetr_pytorch/tools/train.py"
# Out:
# Not init distributed mode.
# Start training
# Downloading: "https://github.com/lyuwenyu/storage/releases/download/v0.1/ResNet18_vd_pretrained_from_paddle.pth" to /root/.cache/torch/hub/checkpoints/ResNet18_vd_pretrained_from_paddle.pth
# 100%|███████████████████████████████████████| 42.8M/42.8M [00:00<00:00, 176MB/s]
# Load PResNet18 state_dict
# Initial lr:  [1e-05, 1e-05, 0.0001, 0.0001]
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# number of params: 20092016
# ...

# %%
# !python "/kaggle/input/rt_detr5/pytorch/default/1/RT_DETR2/RT-DETR/rtdetr_pytorch/tools/export_onnx.py" -c "/kaggle/input/rt_detr5/pytorch/default/1/RT_DETR2/RT-DETR/rtdetr_pytorch/configs/rtdetr/rtdetr_r18vd_6x_coco.yml" -r "/kaggle/working/checkpoint.pth" --check
# Out:
# Load PResNet18 state_dict
# True
# /kaggle/input/rt_detr5/pytorch/default/1/RT_DETR2/RT-DETR/rtdetr_pytorch/tools/../src/zoo/rtdetr/rtdetr_decoder.py:122: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if reference_points.shape[-1] == 2:
# /kaggle/input/rt_detr5/pytorch/default/1/RT_DETR2/RT-DETR/rtdetr_pytorch/tools/../src/zoo/rtdetr/rtdetr_decoder.py:129: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   elif reference_points.shape[-1] == 4:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu117 =============
# ...

# %%
# !python "/kaggle/input/predict/predict.py"

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/kaggle/working/confusion_matrix_test.png'
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')  # Hide axis
plt.show()

# %%
import shutil

# Define the path for the source folder and the zip file
source_folder = '/kaggle/working/output'
zip_file_path = '/kaggle/working/output.zip'

# Compress the folder into a zip file
shutil.make_archive(zip_file_path.replace('.zip', ''), 'zip', source_folder)

print("Folder has been compressed into output.zip")
# Out:
# Folder has been compressed into output.zip
